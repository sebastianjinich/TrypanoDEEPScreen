# %%
import sys; sys.path.insert(0, '..'); sys.path.insert(0, '../utils')
from utils.plots import roc
import pandas as pd

# %%
chembl262 = pd.read_csv("roc_data_262.csv")
chembl2850 = pd.read_csv("roc_data_2850.csv")
chembl4657 = pd.read_csv("roc_data_4657.csv")
chembl5567 = pd.read_csv("roc_data_5567.csv")

# %%
roc(chembl262["true_label"],chembl262["predicted_probability_class_1"])
# Out:
# <div>                            <div id="99b9df28-7036-4862-b7dd-b0a7b4c6dcec" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99b9df28-7036-4862-b7dd-b0a7b4c6dcec")) {                    Plotly.newPlot(                        "99b9df28-7036-4862-b7dd-b0a7b4c6dcec",                        [{"fillpattern":{"shape":""},"hovertemplate":"False Positive Rate=%{x}\u003cbr\u003eTrue Positive Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","x":[0.0,0.0,0.0,0.007462686567164179,0.007462686567164179,0.007462686567164179,0.007462686567164179,0.022388059701492536,0.022388059701492536,0.03731343283582089,0.0
# ...

# %%
roc(chembl2850["true_label"],chembl2850["predicted_probability_class_1"])
# Out:
# <div>                            <div id="41133807-bfa9-4f29-9ee3-1c754124d71e" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41133807-bfa9-4f29-9ee3-1c754124d71e")) {                    Plotly.newPlot(                        "41133807-bfa9-4f29-9ee3-1c754124d71e",                        [{"fillpattern":{"shape":""},"hovertemplate":"False Positive Rate=%{x}\u003cbr\u003eTrue Positive Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","x":[0.0,0.0,0.0,0.0196078431372549,0.0196078431372549,0.0196078431372549,0.0196078431372549,0.0196078431372549,0.0196078431372549,0.0392156862745098,0.03921568627450
# ...

# %%
roc(chembl4657["true_label"],chembl4657["predicted_probability_class_1"])
# Out:
# <div>                            <div id="58c46b88-b005-4c2d-8c45-092a38b77ea9" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58c46b88-b005-4c2d-8c45-092a38b77ea9")) {                    Plotly.newPlot(                        "58c46b88-b005-4c2d-8c45-092a38b77ea9",                        [{"fillpattern":{"shape":""},"hovertemplate":"False Positive Rate=%{x}\u003cbr\u003eTrue Positive Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","x":[0.0,0.0,0.0,0.013422818791946308,0.013422818791946308,0.020134228187919462,0.020134228187919462,0.026845637583892617,0.026845637583892617,0.03355704697986577,0.0
# ...

# %%
roc(chembl5567["true_label"],chembl5567["predicted_probability_class_1"])
# Out:
# <div>                            <div id="4b1a832c-0fbc-4337-a836-4eac014c3138" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b1a832c-0fbc-4337-a836-4eac014c3138")) {                    Plotly.newPlot(                        "4b1a832c-0fbc-4337-a836-4eac014c3138",                        [{"fillpattern":{"shape":""},"hovertemplate":"False Positive Rate=%{x}\u003cbr\u003eTrue Positive Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","x":[0.0,0.0,0.0,0.007692307692307693,0.007692307692307693,0.015384615384615385,0.015384615384615385,0.038461538461538464,0.038461538461538464,0.04230769230769231,0.0
# ...

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(chembl5567["true_label"],chembl5567["predicted_probability_class_1"])
# Out:
# 0.7720192307692307
