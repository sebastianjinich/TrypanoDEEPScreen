# %%
import pandas as pd

# %%
df = pd.read_csv("/home/sjinich/disco/TrypanoDEEPscreen/.data/raw/testing_ensayados_antibioticos.csv")

# %%
df = df.rename(columns={"Name":"comp_id","SMILES":"smiles"})
df
# Out:
#                     Broad_ID       comp_id  \
# 0     BRD-A20839672-003-01-5   cefmenoxime
# 1     BRD-A61633223-001-02-8   ulifloxacin
# 2     BRD-K02275692-300-02-6      cefotiam
# 3     BRD-K96734425-304-01-7   ceftriaxone
# 4     BRD-A47790386-001-03-6  balofloxacin
# ...                      ...           ...
# 4491  BRD-K54142781-003-11-8    cirazoline
# 4492  BRD-K81092066-311-01-6    phenacaine
# 4493  BRD-K10177585-003-02-4        PSB-11
# 4494  BRD-K91874254-001-01-4      CBS-1114
# 4495  BRD-A83650191-004-02-8        A61603
#
#                                                  smiles            Pred_Score  \
# 0     CO\N=C(\C(=O)NC1C2SCC(CSc3nnnn3C)=C(N2C1=O)C(O...     0,967200484871864
# 1          CC1Sc2c(C(O)=O)c(=O)c3cc(F)c(cc3n12)N1CCNCC1     0,957036885619163
# 2     CN(C)CCn1nnnc1SCC1=C(N2[C@H](SC1)[C@H](NC(=O)C...     0,952527394890785
# 3     CO\N=C(/C(=O)N[C@H]1[C@H]2SCC(CSc3nc(=O)c(O)nn...     0,942159757018089
# ...

# %%
df.to_csv("/home/sjinich/disco/TrypanoDEEPscreen/.data/processed/antibiotics_test_predict.csv",index=False)
